# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('raw_data.csv', sep=',', index_col=None)
data.head(10)
# Out:
#   country                 university_name             city  \
# 0  Россия  СПбПУ Петра Великого (Политех)  Санкт-Петербург
# 1  Россия                    УрГЭУ (СИНХ)     Екатеринбург
# 2  Россия           МГТУ им. Г. И. Носова     Магнитогорск
# 3  Россия                          ЮРГУЭС   Константиновск
# 4  Россия                             АГУ              NaN
# 5     NaN                          Майкоп              NaN
# 6  Россия                             МГУ           Москва
# 7  Россия                 МИРЭА (до 2015)           Москва
# 8  Россия                             КГУ           Сургут
# 9  Россия  БВМИ им. Ф. Ф. Ушакова (КВВМУ)      Калининград
#
#                      about                                      activities  \
# 0                      NaN                                             NaN
# 1                      NaN                                             NaN
# 2                      NaN                                             NaN
# 3                      NaN                                             NaN
# 4                      NaN                                             NaN
# 5                      NaN                                             NaN
# 6                      NaN                                             NaN
# 7                      NaN                                             NaN
# 8  хочу всё сразу побольше  найду выгодное решение развитии вашего бизнеса
# 9                      NaN                                             NaN
#
#                                                books games  \
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# 3                                                NaN   NaN
# 4                                                NaN   NaN
# 5                                                NaN   NaN
# 6                                                yoz   NaN
# 7                                                NaN   NaN
# 8  роберт кийосаки богатый папа бедный папа квадр...   NaN
# 9                                                NaN   NaN
#
#                        interests     education_form       education_status  \
# 0                            NaN                NaN                    NaN
# 1                            NaN  заочное отделение   выпускник специалист
# 2                            NaN                NaN                    NaN
# 3                            NaN    очное отделение   студентка специалист
# 4                            NaN                NaN                    NaN
# 5                      экстернат                NaN  Юридический факультет
# 6             bmx extreme sports    очное отделение     выпускник бакалавр
# 7                            NaN                NaN                    NaN
# 8  бизнес финансы семья развитие                NaN                    NaN
# 9                            NaN                NaN                    NaN
#
#                                         faculty_name
# 0                                                NaN
# 1                                            Заочный
# 2                                                NaN
# 3                             Социально-гуманитарный
# 4                                                NaN
# 5                                                NaN
# 6                                         Психологии
# 7                                                NaN
# 8                                                NaN
# 9  Ракетно-артиллерийского вооружения надводных к...

# %%
datav2 = data.drop(columns=['country', 'education_status', 'city', 'education_form', 'education_status'])

datav2 = datav2[
    ~(datav2['about'].isna() 
      & datav2['activities'].isna() 
      & datav2['books'].isna() 
      & datav2['games'].isna() 
      & datav2['interests'].isna()
    )
]
datav2 = datav2[~datav2['university_name'].isna()]
datav2 = datav2[~datav2['faculty_name'].isna()]
datav2 = datav2.fillna('').astype(str)
datav2
# Out:
#                                            university_name  \
# 6                                                      МГУ
# 31                                                    КГМУ
# 32       РАНХиГС при Президенте РФ (бывш. АНХ при Прави...
# 36                                           ОТИ НИЯУ МИФИ
# 39                    한국학중앙연구원 (Academy of Korean Studies)
# ...                                                    ...
# 1307408                            КемГИК (бывш. КемГУКИ)
# 1307425                               ЮУрГГПУ (бывш. ЧГПУ)
# 1307431                                        ЮУрГУ (НИУ)
# 1307432                       КНИТУ-КАИ им. А. Н. Туполева
# 1307437                  Белгородский ГАУ им. В. Я. Горина
#
#                                                      about  \
# 6
# 31       сразу отвечаю часто задаваемы вопросы гкб сп б...
# 32                                умная скромная блондинка
# 36                 очень рисковый мной нелегкозато надёжно
# 39       хороший ♥ c ═════════════════════════════ ║▌│█...
# ...                                                    ...
# 1307408  всё написано абсолютный спам неправда всё напи...
# 1307425  люблю людей ۩۞۩۩۞۩ ۩۞۩۩۞۩ ۩۞۩۩۞۩ ۩۞۩ ۩۞۩ ۩۞۩۩۞...
# 1307431                            чтото нужно написать ох
# 1307432  пpoчиtaйтe oбязateльho bкoнтакте coвмecтнo c f...
# 1307437
#
#                                                 activities  \
# 6
# 31                        врачнейрохирург первой категории
# 32                                   могу просто стесняюсь
# 36
# 39
# ...                                                    ...
# 1307408
# 1307425                               домашний образ жизни
# 1307431  продажа одежды интернете привожу вещи заказ ал...
# 1307432
# 1307437                                      творю красоту
#
#                                                      books  \
# 6                                                      yoz
# 31
# 32       ромео джульетта евгений онегин капитанская доч...
# 36
# 39
# ...                                                    ...
# 1307408
# 1307425                               пахороните плинтусом
# 1307431                 пауло коэлье кен кизи олдос хаксли
# 1307432
# 1307437
#
#                                                      games  \
# 6
# 31
# 32                                   люблю играть беситься
# 36                                                   жизнь
# 39
# ...                                                    ...
# 1307408
# 1307425
# 1307431  желающих сорудничать минимальный оптовый заказ...
# 1307432
# 1307437
#
#                                                  interests  \
# 6                                       bmx extreme sports
# 31                                         обожаю отдыхать
# 32       музыка кино танцы адреналин шоколад книги инте...
# 36
# 39       ssssss sssssss ssssssss ssssssssss ssssssss ss...
# ...                                                    ...
# 1307408
# 1307425                                     наука культура
# 1307431         правила оформления заказа читайте заметках
# 1307432
# 1307437                                                 оч
#
#                                     faculty_name
# 6                                     Психологии
# 31                                      Лечебный
# 32                   Финансов и банковского дела
# 36       Электрификации промышленных предприятий
# 39                                           경제학
# ...                                          ...
# 1307408        Режиссуры и актерского мастерства
# 1307425                             Исторический
# 1307431         Факультет экономики и управления
# 1307432             Экономической теории и права
# 1307437                           Агрономический
#
# [381219 rows x 7 columns]

# %%
from collections import Counter

UNK_TOKEN_IDX = -1
FILL_IDX = 0

class Vocabulary:
    def __init__(self):
        self.word_to_index = dict()
        self.index_to_word = dict()
    
    def add_token(self, token):
        if token not in self.word_to_index:
            index = len(self.word_to_index) + 1
            self.word_to_index[token] = index
            self.index_to_word[index] = token
    
    def __getitem__(self, token):
        return self.word_to_index.get(token, UNK_TOKEN_IDX)
    
    def word(self, index):
        return self.index_to_word.get(index, '<unk>')
    
    def __len__(self):
        return len(self.word_to_index)

class Vectorizer:
    def __init__(self, vocab):
        self.vocab = vocab
    
    def vectorize(self, text: str, vector_lenght: int) -> list:
        vector = np.zeros(vector_lenght)
        indices = [self.vocab[word] for word in text.split()]
        vector[:min(len(indices), vector_lenght)] = indices[:min(len(indices), vector_lenght)]
        
        return vector
    
    @classmethod
    def from_data(cls, data, cutoff=2):
        counter = Counter()
        
        for sample in data:
            for word in sample.split(' '):
                counter[word.strip()] += 1
                
        vocab = Vocabulary()
        
        for word, word_count in counter.items():
            if word_count >= cutoff:
                vocab.add_token(word)
                
        return cls(vocab)

# %%
merged_series = datav2[['about', 'activities', 'books', 'games', 'interests']] \
    .agg(' '.join, axis=1)

datav3 = datav2.drop(columns = ['about', 'activities', 'books', 'games', 'interests'])
datav3['info'] = merged_series

vectorizer = Vectorizer.from_data(merged_series, cutoff=10)
len(vectorizer.vocab)
# Out:
# 78904

# %%
lengths = datav3['info'].apply(lambda x: len(x.split()))

plt.hist(lengths.clip(upper=300), density=True, bins=20)
plt.title(label='Distribution of info lenght')
VEC_SIZE = 50
lengths.describe(), np.quantile(lengths, q=0.7) # Выберем размер набора слов равным 50
# Out:
# (count    381219.000000
#  mean         26.635254
#  std          86.902287
#  min           1.000000
#  25%           5.000000
#  50%          10.000000
#  75%          26.000000
#  max        5068.000000
#  Name: info, dtype: float64,
#  21.0)

# %%
datav4 = datav3.copy()
X = datav4['info'].apply(lambda x: x.strip()).values
y = datav4[['university_name', 'faculty_name']].agg(' ~~~~> '.join, axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KDTree

X_tokenized = np.array([vectorizer.vectorize(text, VEC_SIZE) for text in X])
vocab_max_index = max(vectorizer.vocab.index_to_word.keys())
vocab_min_index = min(vectorizer.vocab.index_to_word.keys())

encoder = LabelEncoder()
Y_labeled = encoder.fit_transform(y)

# %%
from thefuzz import fuzz
from thefuzz import process

correspondences = dict(zip(y, X))
process.extract('аниме тетрадь смерти, туризм, музыка', 
                choices=correspondences, 
                limit=20,
                scorer=fuzz.token_sort_ratio)
# Out:
# [('охота рыбалка туризм музыка',
#   59,
#   'ВА ВПВО ВС РФ (бывш. СВЗРКУ) ~~~~> Инженерный'),
#  ('темная башня  спорт музыка',
#   58,
#   'Университет ИТМО ~~~~> Компьютерных технологий и управления'),
#  ('активный пофигизм   музыка сноуборд туризм',
#   57,
#   'ИГУМО ~~~~> Социология и PR'),
#  ('законы мерфи  музыка спорт танцы',
#   55,
#   'БГТУ им. В. Г. Шухова ~~~~> Институт информационных технологий и управляющих систем'),
#  ('автомобили туризм музыка', 55, 'РГСУ (бывш. РИСИ) ~~~~> ДТИ'),
#  ('нету всякая нету нету музыка',
#   55,
#   'УИУ РАНХиГС при Президенте РФ (бывш. УрАГС) ~~~~> ГМУ'),
#  ('артист режиссер   кино театр музыка книги', 55, 'ГИТИС ~~~~> Актерский'),
#  ('музыка туризм фотографизм',
#   54,
#   'УлГПУ им. И. Н. Ульянова ~~~~> ф-т технологии и предпринимательства'),
#  ('музыка спорт авто техника',
#   54,
#   'ВМИИ (бывш. ЛВВМИУ им. Ленина и ВВМИОЛУ им. Дзержинского) ~~~~> химический'),
#  ('фэнтэзи прятки спорт музыка книги',
#   54,
#   'ЮУрГУ (НИУ) ~~~~> Международных отношений'),
#  ('театр музыка дирижирование ударные инструменты свет звук',
#   53,
#   'РУДН ~~~~> Институт гостиничного бизнеса и туризма'),
#  ('работаю торговой компании   пение музыка',
#   53,
#   'УрФУ им. первого Президента России Б. Н. Ельцина ~~~~> Институт управления и предпринимательства'),
#  ('спорт фитнес туризм походы велосипеды музыка саморазвитие',
#   53,
#   'МГПУ ~~~~> Институт естествознания и спортивных технологий'),
#  ('студент   музыка души пиво угары портачки',
#   52,
#   'МГУИЭ (бывш. МИХМ) ~~~~> Машиностроительный'),
#  ('стивен кинг  музыка спорт', 52, 'БашГУ ~~~~> филологический'),
#  ('спорт музыка восточные танцы',
#   52,
#   'Финансовый университет при Правительстве РФ (бывш. ФА при Правительстве РФ) ~~~~> Финансово-кредитный'),
#  ('актер театра кино   футбол плавание музыка', 51, 'ВГИК ~~~~> Режиссёрский'),
#  ('туризм путешествия искусство архитектура', 51, 'МГПУ ~~~~> Математический'),
#  ('учебник анатомии интелектуальные спорт музыка туризм',
#   51,
#   'СибГУФК ~~~~> Туризма'),
#  ('работа   кино музыка фильмы', 51, 'ОмГПУ ~~~~> Физический')]

# %%
import pickle

class BaselineSolution():
    def __init__(self, correspondences):
        self.correspondences = correspondences

    def find_appropriate_variants(self, text, n=10):
        return process.extract(
            text, 
            choices=self.correspondences,
            limit=n, 
            scorer=fuzz.token_sort_ratio
        )

bsl = BaselineSolution(correspondences)
bsl.find_appropriate_variants('аниме тетрадь смерти, туризм, музыка', n=20)
# Out:
# [('охота рыбалка туризм музыка',
#   59,
#   'ВА ВПВО ВС РФ (бывш. СВЗРКУ) ~~~~> Инженерный'),
#  ('темная башня  спорт музыка',
#   58,
#   'Университет ИТМО ~~~~> Компьютерных технологий и управления'),
#  ('активный пофигизм   музыка сноуборд туризм',
#   57,
#   'ИГУМО ~~~~> Социология и PR'),
#  ('законы мерфи  музыка спорт танцы',
#   55,
#   'БГТУ им. В. Г. Шухова ~~~~> Институт информационных технологий и управляющих систем'),
#  ('автомобили туризм музыка', 55, 'РГСУ (бывш. РИСИ) ~~~~> ДТИ'),
#  ('нету всякая нету нету музыка',
#   55,
#   'УИУ РАНХиГС при Президенте РФ (бывш. УрАГС) ~~~~> ГМУ'),
#  ('артист режиссер   кино театр музыка книги', 55, 'ГИТИС ~~~~> Актерский'),
#  ('музыка туризм фотографизм',
#   54,
#   'УлГПУ им. И. Н. Ульянова ~~~~> ф-т технологии и предпринимательства'),
#  ('музыка спорт авто техника',
#   54,
#   'ВМИИ (бывш. ЛВВМИУ им. Ленина и ВВМИОЛУ им. Дзержинского) ~~~~> химический'),
#  ('фэнтэзи прятки спорт музыка книги',
#   54,
#   'ЮУрГУ (НИУ) ~~~~> Международных отношений'),
#  ('театр музыка дирижирование ударные инструменты свет звук',
#   53,
#   'РУДН ~~~~> Институт гостиничного бизнеса и туризма'),
#  ('работаю торговой компании   пение музыка',
#   53,
#   'УрФУ им. первого Президента России Б. Н. Ельцина ~~~~> Институт управления и предпринимательства'),
#  ('спорт фитнес туризм походы велосипеды музыка саморазвитие',
#   53,
#   'МГПУ ~~~~> Институт естествознания и спортивных технологий'),
#  ('студент   музыка души пиво угары портачки',
#   52,
#   'МГУИЭ (бывш. МИХМ) ~~~~> Машиностроительный'),
#  ('стивен кинг  музыка спорт', 52, 'БашГУ ~~~~> филологический'),
#  ('спорт музыка восточные танцы',
#   52,
#   'Финансовый университет при Правительстве РФ (бывш. ФА при Правительстве РФ) ~~~~> Финансово-кредитный'),
#  ('актер театра кино   футбол плавание музыка', 51, 'ВГИК ~~~~> Режиссёрский'),
#  ('туризм путешествия искусство архитектура', 51, 'МГПУ ~~~~> Математический'),
#  ('учебник анатомии интелектуальные спорт музыка туризм',
#   51,
#   'СибГУФК ~~~~> Туризма'),
#  ('работа   кино музыка фильмы', 51, 'ОмГПУ ~~~~> Физический')]

# %%
with open('correspondences.pickle', 'wb') as f:
    pickle.dump(correspondences, f, protocol=pickle.HIGHEST_PROTOCOL)
